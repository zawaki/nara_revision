# %%
# %load_ext autoreload
from plots import acceptance_ratio, util, failure, acceptance_load, ratio, fragmentation, show_policy_state, load_comparison, load_comparison_cpu, load_comparison_mem, resources_ratio_3d, ratio_distribution, resources_nodes_ratio_3d, resources_nodes_2d, resources_ratio_2d, nodes_ratio_2d, ratio_distribution_slice, resources_nodes_3d, ratio_histogram, failure_3d, failure_histogram, distribution_bars, util_bars, servers_size_bar
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
load_comparison_cpu('../data/test/fabric_flat/load')
# plt.savefig('./figs/uniform/alpha/load_comparison_cpu.png')
load_comparison_mem('../data/test/fabric_flat/load')
# plt.savefig('./figs/uniform/alpha/load_comparison_mem.png')
load_comparison('../data/test/fabric_flat/load')
# plt.savefig('./figs/uniform/alpha/load_comparison.png')

# %%
# %autoreload
fabric = '../data/test/fabric_flat'
data = ['uniform','azure','alibaba']
graph = 'alpha'
files = ['tetris','random','nalb','nulb']

for d in data:
    
    util_bars('{}/{}'.format(fabric,d))
#     plt.savefig('./figs/{}/{}/util_bars_all.png'.format(d,graph,file))
    
#     distribution_bars('{}/{}'.format(fabric,d))
#     plt.savefig('./figs/{}/{}/distribution_bars.png'.format(d,graph,file))
    
#     servers_size_bar('{}/{}'.format(fabric,d))
#     plt.savefig('./figs/{}/{}/servers_bars_all.png'.format(d,graph,file))
    
#     for file in files:
        
#         resources_nodes_3d('{}/{}/{}'.format(fabric,d,file),file)
#         failure_3d('{}/{}/{}'.format(fabric,d,file),file)

#         resources_ratio_3d('{}/{}/{}'.format(fabric,d,file),'{}-{}'.format(file,d))
#         plt.savefig('./figs/{}/{}/{}_resource_ratio_3d.png'.format(d,graph,'{}_{}'.format(file,d)))
        
#         resources_ratio_2d('{}/{}/{}'.format(fabric,d,file),name=file)
#         plt.savefig('./figs/{}/{}/{}_resources_ratio_2d.png'.format(d,graph,file))
        
#         resources_nodes_ratio_3d('{}/{}/{}'.format(fabric,d,file),name=file)
#         plt.savefig('./figs/{}/{}/{}_resources_nodes_3d.png'.format(d,graph,file))
        
#         resources_nodes_2d('{}/{}/{}'.format(fabric,d,file),name='nara-{}'.format(d))
#         plt.savefig('./figs/{}/{}/{}_resources_nodes_2d.png'.format(d,graph,'nara_{}'.format(d)))
        
#         nodes_ratio_2d('{}/{}/{}'.format(fabric,d,file),name='{}-{}'.format('nara',d))
#         plt.savefig('./figs/{}/{}/{}_nodes_ratio.png'.format(d,graph,'{}_{}'.format('nara',d)))
        
#         for i in range(8):
#             ratio_distribution_slice('{}/{}/{}'.format(fabric,d,file),0,(i+1)*10,name='{} {}'.format(file,i))
        
#         acceptance_ratio('{}/{}/{}'.format(fabric,d,file))
#         plt.savefig('./figs/{}/{}/{}_acceptance.png'.format(d,graph,file))

#         ratio('{}/{}/{}'.format(fabric,d,file))
#         plt.savefig('./figs/{}/{}/{}_ratio.png'.format(d,graph,file))

#         fragmentation('{}/{}/{}'.format(fabric,d,file))
#         plt.savefig('./figs/{}_frag_{}.png'.format(d,file))

#         util('{}/{}/{}'.format(fabric,d,file))
#         plt.savefig('./figs/{}/{}/{}_util.png'.format(d,graph,file))

#         failure_histogram('{}/{}/{}'.format(fabric,d,file),name=file,data=d)

#         ratio_histogram('{}/{}/{}'.format(fabric,d,file),name='nara'.format(d))
#         plt.savefig('./figs/{}/alpha/histogram_{}.png'.format(d,'nara'))
#         if file == 'agent':
#             x = 'nara'
#         else:
#             x = file
#         ratio_distribution('{}/{}/{}'.format(fabric,d,file),name=x)

# plt.savefig('./figs/uniform/alpha/distribution.png')
# Out:
# ../data/test/fabric_flat/uniform
# UTILISATION
# {'agent': [0.65060546875, 0.59775390625, 0.5121143671422033, 0.32645102176724405, 0.49929640015352117], 'tetris': [0.5168359375, 0.49542968750000005, 0.35663879431085665, 0.3353505489593599, 0.29448561830428044], 'random': [0.29107421875000006, 0.2806054687499999, 0.1700277481228113, 0.5266252428438605, 0.581289013959829], 'nalb': [0.51583984375, 0.49095703125, 0.39676465011434625, 0.05857434662376959, 0.11658001316403876], 'nulb': [0.23332031250000007, 0.1909375000000001, 0.1500750878156396, 0.03088307398121526, 0.061466313681556195]}
#
#
# ../data/test/fabric_flat/azure
# UTILISATION
# ...

# %%
# %autoreload
import tensorflow as tf
a = tf.convert_to_tensor([1,1,1,2,1,1,1])
