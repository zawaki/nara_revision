# %%
# %load_ext autoreload
from AllocationFuncs.graph_gen import *
import time
#currently RA and AC links have 2 to ensure the same server-server oversub as in small graph

# %%
# %autoreload

fabric(core_per_layer = 2,
        max_core_layers = 4,
        racks_per_pod = 4,
        num_pods = 4,
        server_per_rack = 40,
        show=True,
        save='./graph.txt'
            )

#4,2,2,4

# %%
from NetworkSimulator import NetworkManager
import time

t = time.time()
man = NetworkManager('.')
print(time.time() - t)

t = time.time()
g = man.network.to_dgl_with_edges({'node':['node','mem'],'link':['ports']})
print(time.time() - t)
